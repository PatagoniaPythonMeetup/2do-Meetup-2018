# %% [markdown]
# ## Hola Mundo en R, y algunos ejemplitos
#
# https://irkernel.github.io/

# %%
print('Hello world! en R.')
# Out:
# [1] "Hello world! en R."

# %%
seq(0, 100, length.out=5)
# Out:
# [1]   0  25  50  75 100

# %%
x <- seq(0, 2*pi, length.out=50)
plot(x, sin(x))
# Out:
# plot without title
